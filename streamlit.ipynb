# %%
import streamlit as st
import cv2
import tempfile
from ultralytics import YOLO
from ultralytics.utils.plotting import Annotator, colors
from pytube import YouTube

# Load the YOLO model
model = YOLO("yolov8n.pt")
names = model.names

def process_video(video_path):
    cap = cv2.VideoCapture(video_path)
    assert cap.isOpened(), "Error reading video file"
    w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

    # Blur ratio
    blur_ratio = 50

    # Temporary file to save the output video
    output_path = tempfile.NamedTemporaryFile(suffix='.avi').name
    video_writer = cv2.VideoWriter(output_path, cv2.VideoWriter_fourcc(*"mp4v"), fps, (w, h))

    while cap.isOpened():
        success, im0 = cap.read()
        if not success:
            print("Video frame is empty or video processing has been successfully completed.")
            break

        results = model.predict(im0, show=False)
        boxes = results[0].boxes.xyxy.cpu().tolist()
        clss = results[0].boxes.cls.cpu().tolist()
        annotator = Annotator(im0, line_width=2, example=names)

        if boxes is not None:
            for box, cls in zip(boxes, clss):
                annotator.box_label(box, color=colors(int(cls), True), label=names[int(cls)])

                obj = im0[int(box[1]): int(box[3]), int(box[0]): int(box[2])]
                blur_obj = cv2.blur(obj, (blur_ratio, blur_ratio))

                im0[int(box[1]): int(box[3]), int(box[0]): int(box[2])] = blur_obj

        video_writer.write(im0)
    
    cap.release()
    video_writer.release()
    return output_path

def download_youtube_video(url):
    yt = YouTube(url)
    stream = yt.streams.filter(file_extension='mp4').get_highest_resolution()
    temp_video_path = tempfile.NamedTemporaryFile(delete=False, suffix='.mp4').name
    stream.download(filename=temp_video_path)
    return temp_video_path

# Streamlit app
st.title("Object Blurring with YOLO and OpenCV")

youtube_url = st.text_input("Enter YouTube video URL")

if youtube_url:
    if st.button("Download and Process Video"):
        try:
            temp_video_path = download_youtube_video(youtube_url)
            st.video(temp_video_path)
            output_video_path = process_video(temp_video_path)
            st.success("Video processing completed.")
            st.video(output_video_path)
        except Exception as e:
            st.error(f"Error processing video: {e}")

# %%
pip install streamlit
# Out:
# Requirement already satisfied: streamlit in c:\users\baslv\anaconda3\lib\site-packages (1.30.0)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\baslv\anaconda3\lib\site-packages (from streamlit) (5.0.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\baslv\anaconda3\lib\site-packages (from streamlit) (1.6.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\baslv\anaconda3\lib\site-packages (from streamlit) (4.2.2)
# Requirement already satisfied: click<9,>=7.0 in c:\users\baslv\anaconda3\lib\site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: importlib-metadata<8,>=1.4 in c:\users\baslv\anaconda3\lib\site-packages (from streamlit) (7.0.1)
# Requirement already satisfied: numpy<2,>=1.19.3 in c:\users\baslv\anaconda3\lib\site-packages (from streamlit) (1.25.2)
# Requirement already satisfied: packaging<24,>=16.8 in c:\users\baslv\anaconda3\lib\site-packages (from streamlit) (23.1)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\baslv\anaconda3\lib\site-packages (from streamlit) (2.1.4)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\baslv\anaconda3\lib\site-packages (from streamlit) (10.3.0)
# Requirement already satisfied: protobuf<5,>=3.20 in c:\users\baslv\anaconda3\lib\site-packages (from streamlit) (3.20.3)
# Requirement already satisfied: pyarrow>=6.0 in c:\users\baslv\anaconda3\lib\site-packages (from streamlit) (14.0.2)
# Requirement already satisfied: python-dateutil<3,>=2.7.3 in c:\users\baslv\anaconda3\lib\site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\baslv\anaconda3\lib\site-packages (from streamlit) (2.31.0)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\baslv\anaconda3\lib\site-packages (from streamlit) (13.3.5)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\baslv\anaconda3\lib\site-packages (from streamlit) (8.2.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\baslv\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\baslv\anaconda3\lib\site-packages (from streamlit) (4.9.0)
# Requirement already satisfied: tzlocal<6,>=1.1 in c:\users\baslv\anaconda3\lib\site-packages (from streamlit) (2.1)
# Requirement already satisfied: validators<1,>=0.2 in c:\users\baslv\anaconda3\lib\site-packages (from streamlit) (0.18.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\baslv\anaconda3\lib\site-packages (from streamlit) (3.1.37)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\baslv\anaconda3\lib\site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\baslv\anaconda3\lib\site-packages (from streamlit) (6.3.3)
# Requirement already satisfied: watchdog>=2.1.5 in c:\users\baslv\anaconda3\lib\site-packages (from streamlit) (2.1.6)
# Requirement already satisfied: jinja2 in c:\users\baslv\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.3)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\baslv\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (4.19.2)
# Requirement already satisfied: toolz in c:\users\baslv\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: colorama in c:\users\baslv\anaconda3\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\baslv\anaconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.7)
# Requirement already satisfied: zipp>=0.5 in c:\users\baslv\anaconda3\lib\site-packages (from importlib-metadata<8,>=1.4->streamlit) (3.17.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\baslv\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\baslv\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\baslv\anaconda3\lib\site-packages (from python-dateutil<3,>=2.7.3->streamlit) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\baslv\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\baslv\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\baslv\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\baslv\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2023.7.22)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\baslv\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\baslv\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Requirement already satisfied: decorator>=3.4.0 in c:\users\baslv\anaconda3\lib\site-packages (from validators<1,>=0.2->streamlit) (5.1.1)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\baslv\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\baslv\anaconda3\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\baslv\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\baslv\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\baslv\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\baslv\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.10.6)
# Requirement already satisfied: mdurl~=0.1 in c:\users\baslv\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import streamlit as st
import cv2
import tempfile
from ultralytics import YOLO
from ultralytics.utils.plotting import Annotator, colors
from pytube import YouTube

# Load the YOLO model
model = YOLO("yolov8n.pt")
names = model.names

def process_video(video_path):
    cap = cv2.VideoCapture(video_path)
    assert cap.isOpened(), "Error reading video file"
    w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

    # Blur ratio
    blur_ratio = 50

    # Temporary file to save the output video
    output_path = tempfile.NamedTemporaryFile(suffix='.avi').name
    video_writer = cv2.VideoWriter(output_path, cv2.VideoWriter_fourcc(*"mp4v"), fps, (w, h))

    while cap.isOpened():
        success, im0 = cap.read()
        if not success:
            print("Video frame is empty or video processing has been successfully completed.")
            break

        results = model.predict(im0, show=False)
        boxes = results[0].boxes.xyxy.cpu().tolist()
        clss = results[0].boxes.cls.cpu().tolist()
        annotator = Annotator(im0, line_width=2, example=names)

        if boxes is not None:
            for box, cls in zip(boxes, clss):
                annotator.box_label(box, color=colors(int(cls), True), label=names[int(cls)])

                obj = im0[int(box[1]): int(box[3]), int(box[0]): int(box[2])]
                blur_obj = cv2.blur(obj, (blur_ratio, blur_ratio))

                im0[int(box[1]): int(box[3]), int(box[0]): int(box[2])] = blur_obj

        video_writer.write(im0)
    
    cap.release()
    video_writer.release()
    return output_path

def download_youtube_video(url):
    yt = YouTube(url)
    stream = yt.streams.filter(file_extension='mp4').get_highest_resolution()
    temp_video_path = tempfile.NamedTemporaryFile(delete=False, suffix='.mp4').name
    stream.download(filename=temp_video_path)
    return temp_video_path

# Streamlit app
st.title("Object Blurring with YOLO and OpenCV")

youtube_url = st.text_input("Enter YouTube video URL")

if youtube_url:
    if st.button("Download and Process Video"):
        try:
            temp_video_path = download_youtube_video(youtube_url)
            st.video(temp_video_path)
            output_video_path = process_video(temp_video_path)
            st.success("Video processing completed.")
            st.video(output_video_path)
        except Exception as e:
            st.error(f"Error processing video: {e}")
# Out:
# 2024-05-22 20:10:39.233
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\baslv\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
